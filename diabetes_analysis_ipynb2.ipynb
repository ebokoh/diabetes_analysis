# %% [markdown]
# <a href="https://colab.research.google.com/github/ebokoh/diabetes_analysis/blob/main/diabetes_analysis_ipynb2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Foundations of Data Science Project - Diabetes Analysis<a href="#Foundations-of-Data-Science-Project---Diabetes-Analysis" class="anchor-link">¶</a>
#
# ------------------------------------------------------------------------
#
# ## Context<a href="#Context" class="anchor-link">¶</a>
#
# ------------------------------------------------------------------------
#
# Diabetes is one of the most frequent diseases worldwide and the number
# of diabetic patients are growing over the years. The main cause of
# diabetes remains unknown, yet scientists believe that both genetic
# factors and environmental lifestyle play a major role in diabetes.
#
# A few years ago research was done on a tribe in America which is called
# the Pima tribe (also known as the Pima Indians). In this tribe, it was
# found that the ladies are prone to diabetes very early. Several
# constraints were placed on the selection of these instances from a
# larger database. In particular, all patients were females at least 21
# years old of Pima Indian heritage.
#
# ------------------------------------------------------------------------
#
# ## Objective<a href="#Objective" class="anchor-link">¶</a>
#
# ------------------------------------------------------------------------
#
# Here, we are analyzing different aspects of Diabetes in the Pima Indians
# tribe by doing Exploratory Data Analysis.
#
# ------------------------------------------------------------------------
#
# ## Data Dictionary<a href="#Data-Dictionary" class="anchor-link">¶</a>
#
# ------------------------------------------------------------------------
#
# The dataset has the following information:
#
# -   Pregnancies: Number of times pregnant
# -   Glucose: Plasma glucose concentration over 2 hours in an oral
#     glucose tolerance test
# -   BloodPressure: Diastolic blood pressure (mm Hg)
# -   SkinThickness: Triceps skin fold thickness (mm)
# -   Insulin: 2-Hour serum insulin (mu U/ml)
# -   BMI: Body mass index (weight in kg/(height in m)^2)
# -   DiabetesPedigreeFunction: A function that scores the likelihood of
#     diabetes based on family history.
# -   Age: Age in years
# -   Outcome: Class variable (0: a person is not diabetic or 1: a person
#     is diabetic)
#
# ## Q 1: Import the necessary libraries and briefly explain the use of each library (3 Marks)<a href="#Q-1:-Import-the-necessary-libraries-and-briefly-explain-the-use-of-each-library-(3-Marks)" class="anchor-link">¶</a>
#
# In \[1\]:
#
#     # remove _____ & write the appropriate library name
#
#     import numpy as np
#     import pandas as pd
#
#     import seaborn as sns
#     import matplotlib.pyplot as plt
#     %matplotlib inline
#
# #### Write your Answer here:<a href="#Write-your-Answer-here:" class="anchor-link">¶</a>
#
# Ans 1:Numpy is python library which is mainly used for working with
# arrays. Pandas is an open-source library that is mostly used for
# analysis and manipulation of datasets. Seaborn is data visualization
# library commonly used for exploratory data analysis. Matplotlib is a
# plotting library for visualizations in python. Pyplot is a submodule
# under Matplotlib for MATLAB-like interface
#
# ## Q 2: Read the given dataset (1 Mark)<a href="#Q-2:-Read-the-given-dataset-(1-Mark)" class="anchor-link">¶</a>
#
# In \[2\]:
#
#     # remove _____ & write the appropriate function name
#
#     pima = pd.read_csv("diabetes.csv")
#
# ## Q3. Show the last 10 records of the dataset. How many columns are there? (1 Mark)<a href="#Q3.-Show-the-last-10-records-of-the-dataset.-How-many-columns-are-there?-(1-Mark)" class="anchor-link">¶</a>
#
# In \[3\]:
#
#     # remove ______ and write the appropriate number in the function
#
#     pima.tail(10)
#
# Out\[3\]:
#
# |     | Pregnancies | Glucose | BloodPressure | SkinThickness | Insulin | BMI  | DiabetesPedigreeFunction | Age | Outcome |
# |-----|-------------|---------|---------------|---------------|---------|------|--------------------------|-----|---------|
# | 758 | 1           | 106     | 76            | 20            | 79      | 37.5 | 0.197                    | 26  | 0       |
# | 759 | 6           | 190     | 92            | 20            | 79      | 35.5 | 0.278                    | 66  | 1       |
# | 760 | 2           | 88      | 58            | 26            | 16      | 28.4 | 0.766                    | 22  | 0       |
# | 761 | 9           | 170     | 74            | 31            | 79      | 44.0 | 0.403                    | 43  | 1       |
# | 762 | 9           | 89      | 62            | 20            | 79      | 22.5 | 0.142                    | 33  | 0       |
# | 763 | 10          | 101     | 76            | 48            | 180     | 32.9 | 0.171                    | 63  | 0       |
# | 764 | 2           | 122     | 70            | 27            | 79      | 36.8 | 0.340                    | 27  | 0       |
# | 765 | 5           | 121     | 72            | 23            | 112     | 26.2 | 0.245                    | 30  | 0       |
# | 766 | 1           | 126     | 60            | 20            | 79      | 30.1 | 0.349                    | 47  | 1       |
# | 767 | 1           | 93      | 70            | 31            | 79      | 30.4 | 0.315                    | 23  | 0       |
#
# #### Write your Answer here:<a href="#Write-your-Answer-here:" class="anchor-link">¶</a>
#
# Ans 3:9
#
# ## Q4. Show the first 10 records of the dataset (1 Mark)<a href="#Q4.-Show-the-first-10-records-of-the-dataset-(1-Mark)" class="anchor-link">¶</a>
#
# In \[10\]:
#
#     # remove _____ & write the appropriate function name and the number of rows to get in the output
#
#     pima.head(10)
#
# Out\[10\]:
#
# |     | Pregnancies | Glucose | BloodPressure | SkinThickness | Insulin | BMI       | DiabetesPedigreeFunction | Age | Outcome |
# |-----|-------------|---------|---------------|---------------|---------|-----------|--------------------------|-----|---------|
# | 0   | 6           | 148     | 72            | 35            | 79      | 33.600000 | 0.627                    | 50  | 1       |
# | 1   | 1           | 85      | 66            | 29            | 79      | 26.600000 | 0.351                    | 31  | 0       |
# | 2   | 8           | 183     | 64            | 20            | 79      | 23.300000 | 0.672                    | 32  | 1       |
# | 3   | 1           | 89      | 66            | 23            | 94      | 28.100000 | 0.167                    | 21  | 0       |
# | 4   | 0           | 137     | 40            | 35            | 168     | 43.100000 | 2.288                    | 33  | 1       |
# | 5   | 5           | 116     | 74            | 20            | 79      | 25.600000 | 0.201                    | 30  | 0       |
# | 6   | 3           | 78      | 50            | 32            | 88      | 31.000000 | 0.248                    | 26  | 1       |
# | 7   | 10          | 115     | 69            | 20            | 79      | 35.300000 | 0.134                    | 29  | 0       |
# | 8   | 2           | 197     | 70            | 45            | 543     | 30.500000 | 0.158                    | 53  | 1       |
# | 9   | 8           | 125     | 96            | 20            | 79      | 31.992578 | 0.232                    | 54  | 1       |
#
# ## Q5. What do you understand by the dimension of the dataset? Find the dimension of the `pima` dataframe. (1 Mark)<a href="#Q5.-What-do-you-understand-by-the-dimension-of-the-dataset?-Find-the-dimension-of-the-pima-dataframe.-(1-Mark)" class="anchor-link">¶</a>
#
# In \[11\]:
#
#     # remove _____ & write the appropriate function name
#
#     pima.shape
#
# Out\[11\]:
#
#     (768, 9)
#
# #### Write your Answer here:<a href="#Write-your-Answer-here:" class="anchor-link">¶</a>
#
# Ans 5: Shape of dataset represents the number of rows and the number of
# columns.
#
# ## Q6. What do you understand by the size of the dataset? Find the size of the `pima` dataframe. (1 Mark)<a href="#Q6.-What-do-you-understand-by-the-size-of-the-dataset?-Find-the-size-of-the-pima-dataframe.-(1-Mark)" class="anchor-link">¶</a>
#
# In \[12\]:
#
#     # remove _____ & write the appropriate function name
#
#     pima.size
#
# Out\[12\]:
#
#     6912
#
# #### Write your Answer here:<a href="#Write-your-Answer-here:" class="anchor-link">¶</a>
#
# Ans 6: Size of a dataset is the number of rows multiplied by the number
# of columns.
#
# ## Q7. What are the data types of all the variables in the data set? (2 Marks)<a href="#Q7.-What-are-the-data-types-of-all-the-variables-in-the-data-set?-(2-Marks)" class="anchor-link">¶</a>
#
# **Hint: Use the info() function to get all the information about the
# dataset.**
#
# In \[13\]:
#
#     # remove _____ & write the appropriate function name
#
#     pima.info()
#
#     <class 'pandas.core.frame.DataFrame'>
#     RangeIndex: 768 entries, 0 to 767
#     Data columns (total 9 columns):
#      #   Column                    Non-Null Count  Dtype
#     ---  ------                    --------------  -----
#      0   Pregnancies               768 non-null    int64
#      1   Glucose                   768 non-null    int64
#      2   BloodPressure             768 non-null    int64
#      3   SkinThickness             768 non-null    int64
#      4   Insulin                   768 non-null    int64
#      5   BMI                       768 non-null    float64
#      6   DiabetesPedigreeFunction  768 non-null    float64
#      7   Age                       768 non-null    int64
#      8   Outcome                   768 non-null    int64
#     dtypes: float64(2), int64(7)
#     memory usage: 54.1 KB
#
# #### Write your Answer here:<a href="#Write-your-Answer-here:" class="anchor-link">¶</a>
#
# Ans 7: The data types consists of 2 float64 and 7 int64
#
# ## Q8. What do we mean by missing values? Are there any missing values in the `pima` dataframe? (2 Marks)<a href="#Q8.-What-do-we-mean-by-missing-values?-Are-there-any-missing-values-in-the-pima-dataframe?-(2-Marks)" class="anchor-link">¶</a>
#
# In \[18\]:
#
#     # remove _____ & write the appropriate function name
#
#     pima.isnull().values.any()
#
# Out\[18\]:
#
#     False
#
# #### Write your Answer here:<a href="#Write-your-Answer-here:" class="anchor-link">¶</a>
#
# Ans 8: Missing values represent no information or not available values
# in the dataframe. There are no missing values in the pima dataframe.
#
# ## Q9. What do the summary statistics of the data represent? Find the summary statistics for all variables except 'Outcome' in the `pima` data. Take one column/variable from the output table and explain all its statistical measures. (3 Marks)<a href="#Q9.-What-do-the-summary-statistics-of-the-data-represent?-Find-the-summary-statistics-for-all-variables-except-&#39;Outcome&#39;-in-the-pima-data.-Take-one-column/variable-from-the-output-table-and-explain-all-its-statistical-measures.-(3-Marks)" class="anchor-link">¶</a>
#
# In \[21\]:
#
#     # remove _____ & write the appropriate function name
#
#     pima.iloc[:,0:8].describe()
#
# Out\[21\]:
#
# |       | Pregnancies | Glucose    | BloodPressure | SkinThickness | Insulin    | BMI        | DiabetesPedigreeFunction | Age        |
# |-------|-------------|------------|---------------|---------------|------------|------------|--------------------------|------------|
# | count | 768.000000  | 768.000000 | 768.000000    | 768.000000    | 768.000000 | 768.000000 | 768.000000               | 768.000000 |
# | mean  | 3.845052    | 121.675781 | 72.250000     | 26.447917     | 118.270833 | 32.450805  | 0.471876                 | 33.240885  |
# | std   | 3.369578    | 30.436252  | 12.117203     | 9.733872      | 93.243829  | 6.875374   | 0.331329                 | 11.760232  |
# | min   | 0.000000    | 44.000000  | 24.000000     | 7.000000      | 14.000000  | 18.200000  | 0.078000                 | 21.000000  |
# | 25%   | 1.000000    | 99.750000  | 64.000000     | 20.000000     | 79.000000  | 27.500000  | 0.243750                 | 24.000000  |
# | 50%   | 3.000000    | 117.000000 | 72.000000     | 23.000000     | 79.000000  | 32.000000  | 0.372500                 | 29.000000  |
# | 75%   | 6.000000    | 140.250000 | 80.000000     | 32.000000     | 127.250000 | 36.600000  | 0.626250                 | 41.000000  |
# | max   | 17.000000   | 199.000000 | 122.000000    | 99.000000     | 846.000000 | 67.100000  | 2.420000                 | 81.000000  |
#
# #### Write your Answer here:<a href="#Write-your-Answer-here:" class="anchor-link">¶</a>
#
# Ans 9: Summary statistics demonstrates the basic statistical details of
# a dataframe like mean standard deviation etc. Taking the Age column for
# example: count: shows total number of age entries to be 768 mean: shows
# average of all the age entries to be 33.24 std: shows standard deviation
# of 11.76 min: shows the minimum value of all the age entries to be 21
# 25%: shows the 25 percentile to be 24 50%: shows the 50 percentile or
# median mark to be 29 75%: shows the 75 percentile mark to be 41 max:
# shows the maximum age value to be 81
#
# ## Q 10. Plot the distribution plot for the variable 'BloodPressure'. Write detailed observations from the plot. (2 Marks)<a href="#Q-10.-Plot-the-distribution-plot-for-the-variable-&#39;BloodPressure&#39;.-Write-detailed-observations-from-the-plot.-(2-Marks)" class="anchor-link">¶</a>
#
# In \[25\]:
#
#     # remove _____ & write the appropriate library name
#
#     sns.displot(pima['BloodPressure'], kind='kde')
#     plt.show()
#
# <img src="data:image/png;base64,...%0A" class="jp-needs-light-background" />
#
# #### Write your Answer here:<a href="#Write-your-Answer-here:" class="anchor-link">¶</a>
#
# Ans 10: Most of the data points are centred between 40 and 100. The
# minimum blood pressure is a little above 20 and the maximum is a little
# above 120.
#
# ## Q 11. What is the 'BMI' of the person having the highest 'Glucose'? (1 Mark)<a href="#Q-11.-What-is-the-&#39;BMI&#39;-of-the-person-having-the-highest-&#39;Glucose&#39;?-(1-Mark)" class="anchor-link">¶</a>
#
# In \[39\]:
#
#     # remove _____ & write the appropriate function name
#
#     pima[pima['Glucose']==pima['Glucose'].max()]['BMI']
#
# Out\[39\]:
#
#     661    42.9
#     Name: BMI, dtype: float64
#
# #### Write your Answer here:<a href="#Write-your-Answer-here:" class="anchor-link">¶</a>
#
# Ans 11:BMI of the person with the highest glucose is 42.9
#
# ## Q12.<a href="#Q12." class="anchor-link">¶</a>
#
# ### 12.1 What is the mean of the variable 'BMI'?<a href="#12.1-What-is-the-mean-of-the-variable-&#39;BMI&#39;?" class="anchor-link">¶</a>
#
# ### 12.2 What is the median of the variable 'BMI'?<a href="#12.2-What-is-the-median-of-the-variable-&#39;BMI&#39;?" class="anchor-link">¶</a>
#
# ### 12.3 What is the mode of the variable 'BMI'?<a href="#12.3-What-is-the-mode-of-the-variable-&#39;BMI&#39;?" class="anchor-link">¶</a>
#
# ### 12.4 Are the three measures of central tendency equal?<a href="#12.4-Are-the-three-measures-of-central-tendency-equal?" class="anchor-link">¶</a>
#
# ### (3 Marks)<a href="#(3-Marks)" class="anchor-link">¶</a>
#
# In \[45\]:
#
#     # remove _____ & write the appropriate function name
#
#     m1 = pima['BMI'].mean()  # mean
#     print(m1)
#     m2 = pima['BMI'].median()  # median
#     print(m2)
#     m3 = pima['BMI'].mode()[0]  # mode
#     print(m3)
#
#     32.45080515543617
#     32.0
#     32.0
#
# #### Write your Answer here:<a href="#Write-your-Answer-here:" class="anchor-link">¶</a>
#
# Ans 12:Yes the three measures of central tendency are roughly the same
# which shows a symmetrical distribution.
#
# ## Q13. How many women's 'Glucose' levels are above the mean level of 'Glucose'? (1 Mark)<a href="#Q13.-How-many-women&#39;s-&#39;Glucose&#39;-levels-are-above-the-mean-level-of-&#39;Glucose&#39;?-(1-Mark)" class="anchor-link">¶</a>
#
# In \[48\]:
#
#     # remove _____ & write the appropriate function name
#
#     pima[pima['Glucose']>pima['Glucose'].mean()].shape[0]
#
# Out\[48\]:
#
#     343
#
# #### Write your Answer here:<a href="#Write-your-Answer-here:" class="anchor-link">¶</a>
#
# Ans 13:343
#
# ## Q14. How many women have their 'BloodPressure' equal to the median of 'BloodPressure' and their 'BMI' less than the median of 'BMI'? (2 Marks)<a href="#Q14.-How-many-women-have-their-&#39;BloodPressure&#39;-equal-to-the-median-of-&#39;BloodPressure&#39;-and-their-&#39;BMI&#39;-less-than-the-median-of-&#39;BMI&#39;?-(2-Marks)" class="anchor-link">¶</a>
#
# In \[62\]:
#
#     # remove _____ & write the appropriate column name
#
#     pima[(pima['BloodPressure']==pima['BloodPressure'].median()) & (pima['BMI']<pima['BMI'].median())].shape[0]
#
# Out\[62\]:
#
#     22
#
# #### Write your Answer here:<a href="#Write-your-Answer-here:" class="anchor-link">¶</a>
#
# Ans 14: 22
#
# ## Q15. Create a pairplot for the variables 'Glucose', 'SkinThickness', and 'DiabetesPedigreeFunction'. Write your observations from the plot. (4 Marks)<a href="#Q15.-Create-a-pairplot-for-the-variables-&#39;Glucose&#39;,-&#39;SkinThickness&#39;,-and-&#39;DiabetesPedigreeFunction&#39;.-Write-your-observations-from-the-plot.-(4-Marks)" class="anchor-link">¶</a>
#
# In \[72\]:
#
#     # remove _____ & write the appropriate function name
#
#     sns.pairplot(data=pima,vars=['Glucose', 'SkinThickness', 'DiabetesPedigreeFunction'], hue='Outcome')
#     plt.show()
#
# <img src="data:image/png;base64,...%0A" class="jp-needs-light-background" />
#
# #### Write your Answer here:<a href="#Write-your-Answer-here:" class="anchor-link">¶</a>
#
# Ans 15: Generally, the plot shows there is high glucose levels in
# persons with diabetes. However, there is no strong correlation between
# diabetes pedigree function and glucose. Likewise, there is little
# correlation between skin thickness and glucose.
#
# ## Q16. Plot the scatterplot between 'Glucose' and 'Insulin'. Write your observations from the plot. (2 Marks)<a href="#Q16.-Plot-the-scatterplot-between-&#39;Glucose&#39;-and-&#39;Insulin&#39;.-Write-your-observations-from-the-plot.-(2-Marks)" class="anchor-link">¶</a>
#
# In \[82\]:
#
#     # remove _____ & write the appropriate function name
#
#     sns.lmplot(x='Glucose',y='Insulin',data=pima)
#     plt.show()
#
#     pima[['Glucose','Insulin']].corr()
#
# <img src="data:image/png;base64,...%0A" class="jp-needs-light-background" />
#
# Out\[82\]:
#
# |         | Glucose  | Insulin  |
# |---------|----------|----------|
# | Glucose | 1.000000 | 0.396137 |
# | Insulin | 0.396137 | 1.000000 |
#
# #### Write your Answer here:<a href="#Write-your-Answer-here:" class="anchor-link">¶</a>
#
# Ans 16: The plot indicates weak or some form of correlation between
# insulin and glucose levels. It shows that high insulin levels could some
# how lead to high glucose levels.
#
# ## Q 17. Plot the boxplot for the 'Age' variable. Are there outliers? (2 Marks)<a href="#Q-17.-Plot-the-boxplot-for-the-&#39;Age&#39;-variable.-Are-there-outliers?-(2-Marks)" class="anchor-link">¶</a>
#
# In \[83\]:
#
#     # remove _____ & write the appropriate function and column name
#
#     plt.boxplot(pima['Age'])
#
#     plt.title('Boxplot of Age')
#     plt.ylabel('Age')
#     plt.show()
#
# <img src="data:image/png;base64,...%0A" class="jp-needs-light-background" />
#
# #### Write your Answer here:<a href="#Write-your-Answer-here:" class="anchor-link">¶</a>
#
# Ans 17: From the plot it can be deduced that any range below 20 or above
# 66.5 can be considered as outliers. From the dataset, ages from 67 to 81
# are considered outliers.
#
# ## Q18. Plot histograms for the 'Age' variable to understand the number of women in different age groups given whether they have diabetes or not. Explain both histograms and compare them. (3 Marks)<a href="#Q18.-Plot-histograms-for-the-&#39;Age&#39;-variable-to-understand-the-number-of-women-in-different-age-groups-given-whether-they-have-diabetes-or-not.-Explain-both-histograms-and-compare-them.-(3-Marks)" class="anchor-link">¶</a>
#
# In \[93\]:
#
#     # remove _____ & write the appropriate function and column name
#
#     plt.hist(pima[pima['Outcome']==1]['Age'], bins = 5)
#     plt.title('Distribution of Age for Women who has Diabetes')
#     plt.xlabel('Age')
#     plt.ylabel('Frequency')
#     plt.show()
#
# <img src="data:image/png;base64,...%0A" class="jp-needs-light-background" />
#
# In \[94\]:
#
#     # remove _____ & write the appropriate function and column name
#
#     plt.hist(pima[pima['Outcome']==0]['Age'], bins = 5)
#     plt.title('Distribution of Age for Women who do not have Diabetes')
#     plt.xlabel('Age')
#     plt.ylabel('Frequency')
#     plt.show()
#
# <img src="data:image/png;base64,...%0A" class="jp-needs-light-background" />
#
# #### Write your Answer here:<a href="#Write-your-Answer-here:" class="anchor-link">¶</a>
#
# Ans 18:The first plot shows that the age group of most of the women who
# have diabetes fall within 20 years and 50 years. Between 50 and 70
# years, not so many women. The overall trend indicates that as age
# increases diabetic cases within the sample decreases. The second plot
# also gives a similar trend as the first plot. Majority of the age group
# of women without diabetes fall between 21 and 32 years. The frequency of
# age decreases drastically beyond 32 years. This can also be interpreted
# as that increase in age can lead to increase in diabetes.
#
# ## Q 19. What is the Interquartile Range of all the variables? Why is this used? Which plot visualizes the same? (2 Marks)<a href="#Q-19.-What-is-the-Interquartile-Range-of-all-the-variables?-Why-is-this-used?-Which-plot-visualizes-the-same?-(2-Marks)" class="anchor-link">¶</a>
#
# In \[95\]:
#
#     # remove _____ & write the appropriate variable name
#
#     Q1 = pima.quantile(0.25)
#     Q3 = pima.quantile(0.75)
#     IQR = Q3 - Q1
#     print(IQR)
#
#     Pregnancies                  5.0000
#     Glucose                     40.5000
#     BloodPressure               16.0000
#     SkinThickness               12.0000
#     Insulin                     48.2500
#     BMI                          9.1000
#     DiabetesPedigreeFunction     0.3825
#     Age                         17.0000
#     Outcome                      1.0000
#     dtype: float64
#
# #### Write your Answer here:<a href="#Write-your-Answer-here:" class="anchor-link">¶</a>
#
# Ans 19: IQR shows how spread apart the middle 50% of a dataset is. Box
# plot helps to visualize quartiles and inter quartiles.
#
# ## Q 20. Find and visualize the correlation matrix. Write your observations from the plot. (3 Marks)<a href="#Q-20.-Find-and-visualize-the-correlation-matrix.-Write-your-observations-from-the-plot.-(3-Marks)" class="anchor-link">¶</a>
#
# In \[98\]:
#
#     # remove _____ & write the appropriate function name and run the code
#
#     corr_matrix = pima.iloc[:,0:9].corr()
#
#     corr_matrix
#
# Out\[98\]:
#
# |                          | Pregnancies | Glucose  | BloodPressure | SkinThickness | Insulin   | BMI      | DiabetesPedigreeFunction | Age      | Outcome  |
# |--------------------------|-------------|----------|---------------|---------------|-----------|----------|--------------------------|----------|----------|
# | Pregnancies              | 1.000000    | 0.128022 | 0.208987      | 0.009393      | -0.018780 | 0.021546 | -0.033523                | 0.544341 | 0.221898 |
# | Glucose                  | 0.128022    | 1.000000 | 0.219765      | 0.158060      | 0.396137  | 0.231464 | 0.137158                 | 0.266673 | 0.492884 |
# | BloodPressure            | 0.208987    | 0.219765 | 1.000000      | 0.130403      | 0.010492  | 0.281222 | 0.000471                 | 0.326791 | 0.162879 |
# | SkinThickness            | 0.009393    | 0.158060 | 0.130403      | 1.000000      | 0.245410  | 0.532552 | 0.157196                 | 0.020582 | 0.171857 |
# | Insulin                  | -0.018780   | 0.396137 | 0.010492      | 0.245410      | 1.000000  | 0.189919 | 0.158243                 | 0.037676 | 0.178696 |
# | BMI                      | 0.021546    | 0.231464 | 0.281222      | 0.532552      | 0.189919  | 1.000000 | 0.153508                 | 0.025748 | 0.312254 |
# | DiabetesPedigreeFunction | -0.033523   | 0.137158 | 0.000471      | 0.157196      | 0.158243  | 0.153508 | 1.000000                 | 0.033561 | 0.173844 |
# | Age                      | 0.544341    | 0.266673 | 0.326791      | 0.020582      | 0.037676  | 0.025748 | 0.033561                 | 1.000000 | 0.238356 |
# | Outcome                  | 0.221898    | 0.492884 | 0.162879      | 0.171857      | 0.178696  | 0.312254 | 0.173844                 | 0.238356 | 1.000000 |
#
# In \[99\]:
#
#     # remove _____ & write the appropriate function name
#
#     plt.figure(figsize=(8,8))
#     sns.heatmap(corr_matrix, annot = True)
#
#     # display the plot
#     plt.show()
#
# <img src="data:image/png;base64,...%0A" class="jp-needs-light-background" />
#
# #### Write your Answer here:<a href="#Write-your-Answer-here:" class="anchor-link">¶</a>
#
# Ans 20: From the plot, glucose and BMI show the most correlation with
# diabetes. Pregnancies and age show moderate correlation with diabetes.
# The rest of the variables show little correlation with diabetes. Theres
# is a fairly good correlation between pregnancies and age; skin thickness
# and BMI.
